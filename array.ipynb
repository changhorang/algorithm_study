# %%
def solution(arr):
    arr.sort()
    return arr

arr1 = [4, 2, 2, 1, 3, 4]

print(solution(arr1))

# %%
def solution(arr: list):
    arr.sort()
    result = list
    for i in arr:
        if i not in arr:
            result.append(i)
    
    return result

arr1 = [4, 2, 2, 1, 3, 4]

print(solution(arr1))
